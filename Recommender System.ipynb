# %%
import pandas as pd

# %%
import numpy as np

# %%
pwd
# Out:
# 'C:\\Users\\BITTU'

# %%
cd Desktop\ML3PM\datasets
# Out:
# C:\Users\BITTU\Desktop\ML3PM\datasets

# %%
df=pd.read_csv('movies.csv')
df
# Out:
#       movieId                                              title  \
# 0           1                                   Toy Story (1995)
# 1           2                                     Jumanji (1995)
# 2           3                            Grumpier Old Men (1995)
# 3           4                           Waiting to Exhale (1995)
# 4           5                 Father of the Bride Part II (1995)
# 5           6                                        Heat (1995)
# 6           7                                     Sabrina (1995)
# 7           8                                Tom and Huck (1995)
# 8           9                                Sudden Death (1995)
# 9          10                                   GoldenEye (1995)
# 10         11                     American President, The (1995)
# 11         12                 Dracula: Dead and Loving It (1995)
# 12         13                                       Balto (1995)
# ...

# %%
df.describe()
# Out:
#              movieId
# count    9742.000000
# mean    42200.353623
# std     52160.494854
# min         1.000000
# 25%      3248.250000
# 50%      7300.000000
# 75%     76232.000000
# max    193609.000000

# %%
Ratings=pd.read_csv('ratings.csv')
Ratings.describe()
# Out:
#               userId        movieId         rating     timestamp
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %%
df2=pd.merge(df,Ratings,on='movieId')

# %%
for i in df2.index:
    record= df2.iloc[i,:]
    record= record.dropna()
df2
# Out:
#         movieId                                              title  \
# 0             1                                   Toy Story (1995)
# 1             1                                   Toy Story (1995)
# 2             1                                   Toy Story (1995)
# 3             1                                   Toy Story (1995)
# 4             1                                   Toy Story (1995)
# 5             1                                   Toy Story (1995)
# 6             1                                   Toy Story (1995)
# 7             1                                   Toy Story (1995)
# 8             1                                   Toy Story (1995)
# 9             1                                   Toy Story (1995)
# 10            1                                   Toy Story (1995)
# 11            1                                   Toy Story (1995)
# 12            1                                   Toy Story (1995)
# ...

# %%
req_data=[]
a=input("Enter any genre: ")
for i in df2.index:
    movie=df2.loc[i,'title']
    row=df2.loc[i,'genres']
    rate=df2.loc[i,'rating']
    if type(row) is not float:
        if a in row:
            req_data.append({'title':movie,'genres':row,'rating':rate})
req_data=pd.DataFrame(req_data)
final_req_data=pd.DataFrame(req_data.groupby(['title','genres'])['rating'].mean())
#req_data
final_req_data=final_req_data.dropna()
print(type(rate))
final_req_data.sort_values(by='rating',ascending=False).head(50)
# Out:
# Enter any genre: Comedy
# <class 'numpy.float64'>
#                                                                                       rating
# title                                              genres
# Spellbound (2011)                                  Comedy|Romance                        5.0
# Ex Drummer (2007)                                  Comedy|Crime|Drama|Horror             5.0
# On the Other Side of the Tracks (De l'autre côt... Action|Comedy|Crime                   5.0
# Tom Segura: Completely Normal (2014)               Comedy                                5.0
# Paper Birds (Pájaros de papel) (2010)              Comedy|Drama                          5.0
# Saving Face (2004)                                 Comedy|Drama|Romance                  5.0
# Craig Ferguson: I'm Here To Help (2013)            Comedy|Documentary                    5.0
# Meantime (1984)                                    Comedy|Drama                          5.0
# ...

# %%
movie_matrix = df2.pivot_table(index='userId', columns='title', values='rating')
#movie_matrix.dropna()

# %%
moviedf=pd.DataFrame(movie_matrix)

# %%
film=input("Enter a movie")
til_rating2 = moviedf[film]
similar=moviedf.corrwith(til_rating2)
corr = pd.DataFrame(similar, columns=['Correlation'])
corr.dropna(inplace=True)
corr.head(50)
# Out:
# Enter a movieToy Story (1995)
#                                                     Correlation
# title
# 'burbs, The (1989)                                     0.240563
# (500) Days of Summer (2009)                            0.353833
# *batteries not included (1987)                        -0.427425
# 10 Cent Pistol (2015)                                  1.000000
# 10 Cloverfield Lane (2016)                            -0.285732
# 10 Items or Less (2006)                               -1.000000
# 10 Things I Hate About You (1999)                      0.322741
# 10,000 BC (2008)                                      -0.251279
# 101 Dalmatians (1996)                                  0.580479
# 101 Dalmatians (One Hundred and One Dalmatians)...     0.399643
# 102 Dalmatians (2000)                                 -0.637459
# 11:14 (2003)                                           0.000000
# 12 Angry Men (1957)                                    0.321827
# ...
